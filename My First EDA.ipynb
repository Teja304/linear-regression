# %%
import pandas as pd

# %%
#series

# %%
series_name = pd.Series(["Tom","Raj","Rahul","Tina","Kajol"])

# %%
series_name
# Out:
# 0      Tom
# 1      Raj
# 2    Rahul
# 3     Tina
# 4    Kajol
# dtype: object

# %%
roll=["roll-1","roll-2","roll-3","roll-4","roll-5"]

# %%
series_name = pd.Series(["Tom","Raj","Rahul","Tina","Kajol"],index=roll)

# %%
series_name
# Out:
# roll-1      Tom
# roll-2      Raj
# roll-3    Rahul
# roll-4     Tina
# roll-5    Kajol
# dtype: object

# %%
dict_name={"roll-1":"Tom","roll-2":"Raj","roll-3":"Rahul","roll-4":"Tina","roll-5":"Kajol"}

# %%
dict_name
# Out:
# {'roll-1': 'Tom',
#  'roll-2': 'Raj',
#  'roll-3': 'Rahul',
#  'roll-4': 'Tina',
#  'roll-5': 'Kajol'}

# %%
name = pd.Series(dict_name)

# %%
name
# Out:
# roll-1      Tom
# roll-2      Raj
# roll-3    Rahul
# roll-4     Tina
# roll-5    Kajol
# dtype: object

# %%
nums= [800678,800456]

# %%
names = ["Richie","Mark"]

# %%
series_1 = pd.Series(nums)

# %%
series_2 = pd.Series(nums,index=names)

# %%
print(series_1)
# Out:
# 0    800678
# 1    800456
# dtype: int64

# %%
print(series_2)
# Out:
# Richie    800678
# Mark      800456
# dtype: int64

# %%
name=pd.Series('Tom','James','Ricky','Vin','Steve','Smith','Jack')
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-20-0b7c0005fb8a> in <module>
# ----> 1 name=pd.Series('Tom','James','Ricky','Vin','Steve','Smith','Jack')
#
# TypeError: __init__() takes from 1 to 7 positional arguments but 8 were given

# %%
name=pd.Series(['Tom','James','Ricky','Vin','Steve','Smith','Jack'])

# %%
age=pd.Series([25,26,25,23,30,29,23])

# %%
rating=pd.Series([4.23,3.24,3.98,2.56,3.20,4.6,3.8])

# %%
dict1={"Name":name,"Age":age,"Rating":rating}

# %%
df_stud=pd.DataFrame(dict1)

# %%
df_stud
# Out:
#     Name  Age  Rating
# 0    Tom   25    4.23
# 1  James   26    3.24
# 2  Ricky   25    3.98
# 3    Vin   23    2.56
# 4  Steve   30    3.20
# 5  Smith   29    4.60
# 6   Jack   23    3.80

# %%
df_stud1 = df_stud.T

# %%
df_stud1
# Out:
#            0      1      2     3      4      5     6
# Name     Tom  James  Ricky   Vin  Steve  Smith  Jack
# Age       25     26     25    23     30     29    23
# Rating  4.23   3.24   3.98  2.56    3.2    4.6   3.8

# %%
df_stud.dtypes
# Out:
# Name       object
# Age         int64
# Rating    float64
# dtype: object

# %%
df_stud.head(2)
# Out:
#     Name  Age  Rating
# 0    Tom   25    4.23
# 1  James   26    3.24

# %%
df_stud.tail(2)
# Out:
#     Name  Age  Rating
# 5  Smith   29     4.6
# 6   Jack   23     3.8

# %%
df_stud.shape
# Out:
# (7, 3)

# %%
#print the first two rows
df_stud.iloc[0:2,:]
# Out:
#     Name  Age  Rating
# 0    Tom   25    4.23
# 1  James   26    3.24

# %%
#print the first 2 columns
df_stud.iloc[:,0:2]
# Out:
#     Name  Age
# 0    Tom   25
# 1  James   26
# 2  Ricky   25
# 3    Vin   23
# 4  Steve   30
# 5  Smith   29
# 6   Jack   23

# %%
#to print the first and third column
df_stud.iloc[:,[0,2]]
# Out:
#     Name  Rating
# 0    Tom    4.23
# 1  James    3.24
# 2  Ricky    3.98
# 3    Vin    2.56
# 4  Steve    3.20
# 5  Smith    4.60
# 6   Jack    3.80

# %%
#print second, fourth and sixth row
df_stud.iloc[[1,3,5],:]
# Out:
#     Name  Age  Rating
# 1  James   26    3.24
# 3    Vin   23    2.56
# 5  Smith   29    4.60

# %%
#renaming a column
df_stud.rename(columns={"Name":"First_name"},inplace=True)

# %%
df_stud.rename(columns={"Rating":"Score"},inplace=True)

# %%
df_stud
# Out:
#   First_name  Age  Score
# 0        Tom   25   4.23
# 1      James   26   3.24
# 2      Ricky   25   3.98
# 3        Vin   23   2.56
# 4      Steve   30   3.20
# 5      Smith   29   4.60
# 6       Jack   23   3.80

# %%
df_stud1=df_stud.drop("Score",axis=1)

# %%
df_stud1
# Out:
#   First_name  Age
# 0        Tom   25
# 1      James   26
# 2      Ricky   25
# 3        Vin   23
# 4      Steve   30
# 5      Smith   29
# 6       Jack   23

# %%
df_stud2 = df_stud.drop(1,axis=0)

# %%
df_stud2
# Out:
#   First_name  Age  Score
# 0        Tom   25   4.23
# 2      Ricky   25   3.98
# 3        Vin   23   2.56
# 4      Steve   30   3.20
# 5      Smith   29   4.60
# 6       Jack   23   3.80

# %%
#sort the data by rating
df_stud.sort_values(by="Score")
# Out:
#   First_name  Age  Score
# 3        Vin   23   2.56
# 4      Steve   30   3.20
# 1      James   26   3.24
# 6       Jack   23   3.80
# 2      Ricky   25   3.98
# 0        Tom   25   4.23
# 5      Smith   29   4.60

# %%
df_stud.sort_values(by="Score",ascending=False)
# Out:
#   First_name  Age  Score
# 5      Smith   29   4.60
# 0        Tom   25   4.23
# 2      Ricky   25   3.98
# 6       Jack   23   3.80
# 1      James   26   3.24
# 4      Steve   30   3.20
# 3        Vin   23   2.56

# %%
df_stud[(df_stud["Age"]>=23) & (df_stud["Age"]<=25)]
# Out:
#   First_name  Age  Score
# 0        Tom   25   4.23
# 2      Ricky   25   3.98
# 3        Vin   23   2.56
# 6       Jack   23   3.80

# %%
#print the records of Smith or James
df_stud[(df_stud["First_name"]=="Smith") | (df_stud["First_name"]=="James")]
# Out:
#   First_name  Age  Score
# 1      James   26   3.24
# 5      Smith   29   4.60

# %%
df_grade=read.csv("E:\rstudio files\grade_score.csv")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-61-09bef94953de> in <module>
# ----> 1 df_grade=read.csv("E:\rstudio files\grade_score.csv")
#
# NameError: name 'read' is not defined
