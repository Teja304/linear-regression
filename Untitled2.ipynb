# %%
import pandas as pd

# %%
df_boston=pd.read_csv("E:/idrani maam/boston_dataset.csv")

# %%
df_boston=

# %%
df_boston.kurtosis()
# Out:
# Unnamed: 0    -1.200000
# crim          37.130509
# zn             4.031510
# indus         -1.233540
# chas           9.638264
# nox           -0.064667
# rm             1.891500
# age           -0.967716
# dis            0.487941
# rad           -0.867232
# tax           -1.142408
# ptratio       -0.285091
# black          7.226818
# lstat          0.493240
# medv           1.495197
# dtype: float64

# %%
df_kurtosis = df_boston.kurtosis()
df_kurtosis[(df_kurtosis>3)].index
# Out:
# Index(['crim', 'zn', 'chas', 'black'], dtype='object')

# %%
df_skew=df_boston.skew()

# %%
col=df_skew[(df_skew.values)]
